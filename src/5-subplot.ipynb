# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt  
import numpy as np  

# Data for the plots  
x = np.linspace(0, 10, 100)  # X values for line plot  
y_line = np.sin(x)            # Y values for line plot  

categories = ['A', 'B', 'C', 'D']  
bar_values = [5, 7, 3, 9]     # Values for bar chart  

scatter_x = [1, 2, 3, 4, 5]   # X values for scatter plot  
scatter_y = [2, 4, 6, 8, 10]   # Y values for scatter plot  

pie_labels = ['Python', 'Java', 'C++', 'JavaScript']  
pie_sizes = [40, 25, 20, 15]   # Values for pie chart  

# Create a 2x2 subplot layout  
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  

# First subplot: Line chart  
axs[0, 0].plot(x, y_line, color='blue')  
axs[0, 0].set_title('Line Chart: y = sin(x)')  
axs[0, 0].set_xlabel('X values')  
axs[0, 0].set_ylabel('Y values')  

# Second subplot: Bar chart  
axs[0, 1].bar(categories, bar_values, color='green')  
axs[0, 1].set_title('Bar Chart of Categories')  
axs[0, 1].set_ylabel('Values')  

# Third subplot: Scatter plot  
axs[1, 0].scatter(scatter_x, scatter_y, color='orange', marker='o')  
axs[1, 0].set_title('Scatter Plot')  
axs[1, 0].set_xlabel('X values')  
axs[1, 0].set_ylabel('Y values')  

# Fourth subplot: Pie chart  
axs[1, 1].pie(pie_sizes, labels=pie_labels, autopct='%1.1f%%', startangle=140)  
axs[1, 1].set_title('Programming Language Popularity')  

# Adjust layout to prevent overlap  
plt.tight_layout()  

# Show the plots  
plt.show()
